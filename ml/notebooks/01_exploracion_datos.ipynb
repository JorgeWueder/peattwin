# %% [markdown]
# # Exploracion de datos - PeatTwin
#
# Notebook de ejemplo para la exploracion inicial de datos de turberas.
# Ejecutar Jupyter desde la raiz del repositorio para que el paquete `ml` sea importable.

# %%
from ml.src.data import make_synthetic_dataset

df = make_synthetic_dataset()
df.describe()
